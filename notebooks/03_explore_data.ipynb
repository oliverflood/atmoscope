# %%
import json
import pandas as pd
import os
import requests
from tqdm import tqdm

# %%
file_path = "../data/raw/sky_conditions_20250815_20250901.json"

with open(file_path, 'r') as f:
    data = json.load(f)

observations = data['results']
# print(data.keys())
# print(data['count'])
# print(data['message'])
print(json.dumps(data['results'][0], indent=2))
# Out:
# {
#   "protocol": "sky_conditions",
#   "measuredDate": "2025-09-01",
#   "createDate": "2025-09-01T09:10:03",
#   "updateDate": "2025-09-01T09:10:03",
#   "publishDate": "2025-09-01T09:20:00",
#   "organizationId": 246148,
#   "organizationName": "Dome International Schools at Riyadh",
#   "siteId": 13092,
#   "siteName": "Dome2025",
#   "countryName": "Saudi Arabia",
#   "countryCode": "SAU",
#   "latitude": 24.810544,
#   "longitude": 46.605098,
#   "elevation": 603.8,
#   "pid": 211340542,
#   "data": {
#     "skyconditionsSand": null,
#     "skyconditionsDownwardCaption": null,
#     "skyconditionsFog": null,
#     "skyconditionsNimbostratus": null,
#     "skyconditionsOpacityLow": null,
#     "skyconditionsWestCaption": null,
#     "skyconditionsCloudCoverHigh": "isolated",
#     "skyconditionsDownwardPhotoUrl": null,
#     "skyconditionsVolcanicAsh": null,
#     "skyconditionsLeavesOnTrees": false,
#     "skyconditionsMeasuredAt": "2025-09-01T09:00:00",
#     "skyconditionsFeature2PhotoUrl": null,
#     "skyconditionsFeature4PhotoUrl": null,
#     "skyconditionsCirrostratus": true,
#     "skyconditionsRainingSnowing": false,
#     "skyconditionsContrailCoverDeprecated": null,
#     "skyconditionsCirrocumulus": null,
#     "skyconditionsCumulus": null,
#     "skyconditionsCirrus": true,
#     "skyconditionsHaze": null,
#     "skyconditionsNorthCaption": null,
#     "skyconditionsCumulonimbus": null,
#     "skyconditionsSolarMeasuredAt": "2025-09-01T12:06:00",
#     "skyconditionsMuddy": false,
#     "skyconditionsSkyClarity": "clear",
#     "skyconditionsUpwardPhotoUrl": null,
#     "skyconditionsIsGlobeTrained": true,
#     "skyconditionsShortLivedContrails": 0,
#     "skyconditionsSmoke": null,
#     "skyconditionsWestPhotoUrl": null,
#     "skyconditionsSouthCaption": null,
#     "skyconditionsObservationId": "150-13092-3074274-202509010900",
#     "skyconditionsCloudCoverMid": null,
#     "skyconditionsUserid": 3074274,
#     "skyconditionsEastCaption": null,
#     "skyconditionsStratocumulus": null,
#     "skyconditionsBlowingSnow": null,
#     "skyconditionsSouthPhotoUrl": null,
#     "skyconditionsFeature4Caption": null,
#     "skyconditionsFeature2Caption": null,
#     "skyconditionsIsCitizenScience": false,
#     "skyconditionsFeature1Caption": null,
#     "skyconditionsFeature3Caption": null,
#     "skyconditionsCloudCoverLow": null,
#     "skyconditionsNorthPhotoUrl": null,
#     "skyconditionsUpwardCaption": null,
#     "skyconditionsFeature3PhotoUrl": null,
#     "skyconditionsSpreadingContrails": 0,
#     "skyconditionsStratus": null,
#     "skyconditionsDust": null,
#     "skyconditionsComments": null,
#     "skyconditionsDataSource": "GLOBE Data Entry Web Forms",
#     "skyconditionsSkyColor": "light blue",
#     "skyconditionsOpacityHigh": null,
#     "skyconditionsSkyConditionId": 4549628,
#     "skyconditionsFeature1PhotoUrl": null,
#     "skyconditionsNonSpreadingContrails": 0,
#     "skyconditionsDryGround": true,
#     "skyconditionsHeavySnow": null,
#     "skyconditionsCloudCover": "isolated",
#     "skyconditionsAltostratus": null,
#     "skyconditionsSnowIce": false,
#     "skyconditionsAltocumulus": null,
#     "skyconditionsOpacityMid": null,
#     "skyconditionsEastPhotoUrl": null,
#     "skyconditionsStandingWater": false,
#     "skyconditionsSpray": null,
#     "skyconditionsHeavyRain": null
#   }
# }
